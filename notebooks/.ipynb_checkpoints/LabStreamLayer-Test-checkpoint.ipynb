# %%
import numpy as np
from pylsl import StreamInlet, resolve_byprop
from tqdm import tqdm

streams = resolve_byprop('name', 'PiEEG')
inlet = StreamInlet(streams[0])


samples = []
timestamps = []

for i in tqdm(range(5000)):
    sample, timestamp = inlet.pull_sample()
    samples.append(sample)
    timestamps.append(timestamp)
# Out:
# 2026-05-28 16:19:49.675 (   0.006s) [          5284DE]         api_config.cpp:126   INFO| Loaded default config

# %%
samples = np.asarray(samples)
timestamps = np.asarray(timestamps)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 samples = np.asarray(samples)
#       2 timestamps = np.asarray(timestamps)
#
# NameError: name 'np' is not defined

# %%
import matplotlib.pyplot as plt
plt.plot(timestamps,  samples[:, 1] )
