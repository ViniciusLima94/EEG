# %% [markdown]
# # EEG · Live BCI Prediction Demo
#
# Loads the trained LightGBM model saved by `eeg_lgb_focused.ipynb`, replays one
# trial sample-by-sample and renders an `.mp4` that simulates real-time inference.
#
# **Layout**
# - **4 × 4 panels** — the 16 EEG channels (4 s scrolling window, CORAL when detecting)
# - **Bottom panel** — smoothed LightGBM probability + button-press events (30 s scrolling)
#
# Run `lgb-save` in `eeg_lgb_focused.ipynb` first to generate `models/lgb_demo.pkl`.

# %%
import os
import pickle
import sys

import matplotlib
import numpy as np
import pandas as pd

matplotlib.use("Agg")  # off-screen backend for FuncAnimation.save()
import matplotlib.animation as animation
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from scipy.signal import welch

sys.path.insert(0, "..")
from src.preprocessing import load_trial

DARK, CARD, EDGE = "#0a0e17", "#111827", "#1f2937"
TEAL, CORAL, GOLD, WHITE = "#00e5cc", "#ff4f5e", "#ffc947", "#f0f4ff"

print("Imports OK")

# %%
with open("models/lgb_pipeline_opt.pkl", "rb") as f:
    art = pickle.load(f)

model = art["model"]
USE_EA = bool(art.get("USE_EA", False))
W = art.get("W", None)
MF_TEMPLATE = art.get("mf_template", None)  # (T_OPT, N_CH) or None
T_OPT = art["T_OPT"]
FS = art["FS"]
DECIM = art["DECIM"]
FS_EFF = art["FS_EFF"]
LP = art["LP"]
HP = art["HP"]
HORIZON = art["HORIZON"]
SMOOTH_WIN = art["SMOOTH_WIN"]
REFRACTORY = int(art.get("REFRACTORY", FS_EFF))
PERSIST_K = int(art.get("PERSIST_K", 1))
thresh = art["thresh"]
EEG_COLS = art["EEG_COLS"]
N_CH = len(EEG_COLS)

# ── Configurable ──────────────────────────────────────────────────────────────
SUBJECT = 0
TACHE = "gng_clean"  # ICA-cleaned data
DEMO_TRIAL = 11  # any trial in TEST_TRIALS (1–9)
DATA_PATH = f"../data/subject{SUBJECT}/"
DESPIKE_SIGMA = 5.0
SKIP_SECONDS = 20.0

mf_str = f"yes  shape={MF_TEMPLATE.shape}" if MF_TEMPLATE is not None else "no"
print(f"Model loaded   Subject={SUBJECT}  tache={TACHE}  Demo trial={DEMO_TRIAL}")
print(
    f"T_OPT={T_OPT} ({T_OPT/FS_EFF*1000:.0f} ms)  thresh={thresh:.4f}  "
    f"FS_EFF={FS_EFF} Hz  USE_EA={USE_EA}  MF={mf_str}"
)
print(
    f"PERSIST_K={PERSIST_K} ({PERSIST_K/FS_EFF*1000:.0f} ms)  "
    f"REFRACTORY={REFRACTORY/FS_EFF*1000:.0f} ms  "
    f"HORIZON={HORIZON/FS_EFF*1000:.0f} ms"
)

# %%
df, _ = load_trial(
    SUBJECT,
    TACHE,
    DEMO_TRIAL,
    DATA_PATH,
    eeg_cols=EEG_COLS,
    fs=FS,
    lp=LP,
    hp=HP,
    apply_filter=True,
    car=True,
    trial_zscore=True,
    clip_percentile=1.0,
    decimate=DECIM,
    despike_sigma=DESPIKE_SIGMA,
    skip_seconds=SKIP_SECONDS,
)
X_raw = df[EEG_COLS].values.astype(np.float32)  # (N_samp, C)  already decimated
y_mom = df["button"].values.astype(np.int8)
N_samp = len(X_raw)

press_times = np.where(y_mom > 0)[0] / FS_EFF
print(
    f"Trial {DEMO_TRIAL}: {N_samp} samples ({N_samp/FS_EFF:.1f} s)  "
    f"presses={len(press_times)}"
)

# %%
# ── Feature functions (exact match with eeg_lgb_focused.ipynb) ───────────────


def temporal_features(X3d, n_segs=4):
    """(N, T, C) → (N, C*(6+n_segs))  base stats + CNV ramp profile."""
    N, T, C = X3d.shape
    X64 = X3d.astype(np.float64)
    t_c = np.arange(T, dtype=np.float64) - (T - 1) / 2.0
    t_var = (t_c**2).sum() + 1e-12
    mean_ = X64.mean(axis=1)
    std_ = X64.std(axis=1)
    slope_ = (X64 * t_c[None, :, None]).sum(axis=1) / t_var
    min_ = X64.min(axis=1)
    argm_ = X64.argmin(axis=1) / T
    rms_ = np.sqrt((X64**2).mean(axis=1))
    base = np.stack([mean_, std_, slope_, min_, argm_, rms_], axis=2)  # (N, C, 6)
    seg_size = max(1, T // n_segs)
    segs = np.stack(
        [
            X64[:, i * seg_size : (i + 1) * seg_size, :].mean(axis=1)
            for i in range(n_segs)
        ],
        axis=2,
    )  # (N, C, n_segs)
    return (
        np.concatenate([base, segs], axis=2)
        .reshape(N, C * (6 + n_segs))
        .astype(np.float32)
    )


def freq_features(X3d, fs, batch=2000):
    N, T, C = X3d.shape
    nperseg = min(T, 64)
    out = np.zeros((N, C * 5), dtype=np.float32)
    for s in range(0, N, batch):
        xb = X3d[s : s + batch].transpose(0, 2, 1)
        f, p = welch(xb, fs=fs, nperseg=nperseg, axis=-1)
        df_ = f[1] - f[0]
        dp = p[:, :, (f >= 0.5) & (f <= 4.0)].sum(-1) * df_
        tp = p[:, :, (f >= 4.0) & (f <= 8.0)].sum(-1) * df_
        al = p[:, :, (f >= 8.0) & (f <= 13.0)].sum(-1) * df_
        be = p[:, :, (f >= 13.0) & (f <= 28.0)].sum(-1) * df_
        ma = f > 0
        pn = p[:, :, ma] / (p[:, :, ma].sum(-1, keepdims=True) + 1e-12)
        se = -(pn * np.log(pn + 1e-12)).sum(-1)
        out[s : s + batch, 0::5] = dp
        out[s : s + batch, 1::5] = tp
        out[s : s + batch, 2::5] = al
        out[s : s + batch, 3::5] = be
        out[s : s + batch, 4::5] = se
    return out


def hjorth_features(X3d):
    d1 = np.diff(X3d, axis=1)
    d2 = np.diff(d1, axis=1)
    v0 = X3d.var(axis=1) + 1e-12
    v1 = d1.var(axis=1) + 1e-12
    v2 = d2.var(axis=1) + 1e-12
    mob = np.sqrt(v1 / v0)
    cmp = np.sqrt(v2 / v1) / (mob + 1e-12)
    return np.stack([v0, mob, cmp], axis=2).reshape(len(X3d), -1).astype(np.float32)


def mf_features(X3d, template):
    """Per-channel matched-filter correlation with normalised template. (N, C)"""
    t_norm = (template - template.mean(0)) / (template.std(0) + 1e-8)
    mu = X3d.mean(axis=1, keepdims=True)
    sd = X3d.std(axis=1, keepdims=True) + 1e-8
    return ((X3d - mu) / sd * t_norm[None]).mean(axis=1).astype(np.float32)


def compute_features(X3d, fs):
    parts = [temporal_features(X3d), freq_features(X3d, fs), hjorth_features(X3d)]
    if MF_TEMPLATE is not None:
        parts.append(mf_features(X3d, MF_TEMPLATE))
    return np.concatenate(parts, axis=1).astype(np.float32)


# ── Build all sliding windows ─────────────────────────────────────────────────
N_wins = N_samp - T_OPT
print(f"Building {N_wins:,} windows (N_samp={N_samp}, T_OPT={T_OPT}) …")
idx_mat = np.arange(N_wins)[:, None] + np.arange(T_OPT)[None, :]
X_wins = X_raw[idx_mat]  # (N_wins, T_OPT, C)

if USE_EA and W is not None:
    print("Applying Euclidean Alignment …")
    X_wins = (X_wins @ W.T).astype(np.float32)

# Compute features in batches
BATCH = 2000
print("Computing features …", end="", flush=True)
feats = []
for i in range(0, N_wins, BATCH):
    feats.append(compute_features(X_wins[i : i + BATCH], FS_EFF))
    if (i // BATCH) % 10 == 0:
        print(f" {i // BATCH}", end="", flush=True)
X_feat = np.concatenate(feats)
del X_wins, feats
print(f"\n  {X_feat.shape[1]} features per window")

# Wrap in DataFrame using the model's stored column names to silence sklearn warning
feat_names = getattr(model, "feature_names_in_", None)
X_pred = pd.DataFrame(X_feat, columns=feat_names) if feat_names is not None else X_feat
del X_feat

# Predict → smooth → persistence gate (matches evaluation pipeline)
print("Predicting …")
scores_raw = model.predict_proba(X_pred)[:, 1].astype(np.float32)
scores_smooth = (
    pd.Series(scores_raw)
    .rolling(SMOOTH_WIN, min_periods=1)
    .mean()
    .values.astype(np.float32)
)
scores_gated = (
    pd.Series(scores_smooth)
    .rolling(PERSIST_K, min_periods=1)
    .min()
    .values.astype(np.float32)
)
del X_pred

det_frac = (scores_gated >= thresh).mean() * 100
print(
    f"Done. max_raw={scores_raw.max():.3f}  max_gated={scores_gated.max():.3f}  "
    f"above threshold={det_frac:.1f}%"
)

# %%
# ── Animation parameters ─────────────────────────────────────────────────────
FPS = 15  # display frame-rate
STEP = max(1, FS_EFF // FPS * 3)  # advance per frame → ~3× real-time
EEG_WIN_S = 4.0  # seconds of EEG visible per channel
EEG_WIN = int(EEG_WIN_S * FS_EFF)
PROB_WIN_S = 30.0  # seconds of probability history visible
PROB_WIN = int(PROB_WIN_S * FS_EFF)
N_frames = (N_wins - 1) // STEP

# Precomputed time axes
t_wins = (T_OPT + np.arange(N_wins)) / FS_EFF  # absolute time per window
t_eeg_rel = np.arange(-EEG_WIN, 0) / FS_EFF  # fixed relative axis for EEG

# EEG y-limits (symmetric around 0, robust to spikes)
eeg_p99 = float(np.percentile(np.abs(X_raw), 99))
eeg_ylim = (-eeg_p99 * 1.25, eeg_p99 * 1.25)

# ── Figure ────────────────────────────────────────────────────────────────────
fig = plt.figure(figsize=(18, 13), facecolor=DARK)
gs = GridSpec(
    5, 4, figure=fig, height_ratios=[1, 1, 1, 1, 1.8], hspace=0.38, wspace=0.18
)

# 4 × 4 EEG panels
ax_eeg_flat = []
for r in range(4):
    for c in range(4):
        ax = fig.add_subplot(gs[r, c])
        ax.set_facecolor(CARD)
        for sp in ax.spines.values():
            sp.set_color(EDGE)
        ax.tick_params(colors=WHITE, labelsize=5, length=2, pad=1)
        ax.set_xlim(-EEG_WIN_S, 0)
        ax.set_ylim(*eeg_ylim)
        ax.set_title(EEG_COLS[r * 4 + c], color=WHITE, fontsize=7, pad=2)
        if c == 0:
            ax.set_ylabel("µV", color=WHITE, fontsize=5)
        ax_eeg_flat.append(ax)

# Bottom probability panel
ax_prob = fig.add_subplot(gs[4, :])
ax_prob.set_facecolor(CARD)
for sp in ax_prob.spines.values():
    sp.set_color(EDGE)
ax_prob.tick_params(colors=WHITE, labelsize=8)
ax_prob.set_ylim(-0.05, 1.10)
ax_prob.set_ylabel("P(press)", color=WHITE, fontsize=9)
ax_prob.set_xlabel("Time (s)", color=WHITE, fontsize=9)

# Static decoration
ax_prob.axhline(thresh, color=CORAL, lw=1.5, ls="--", alpha=0.9, zorder=3)
for pt in press_times:
    ax_prob.axvspan(
        max(0.0, pt - HORIZON / FS_EFF), pt, alpha=0.15, color=GOLD, zorder=1
    )
    ax_prob.axvline(pt, color=WHITE, lw=0.7, alpha=0.5, zorder=4)

# Legend
leg_handles = [
    mpatches.Patch(color=TEAL, label="P(press) smooth"),
    mpatches.Patch(color="#a0c4ff", alpha=0.85, label="P(press) gated"),
    plt.Line2D(
        [0], [0], color=CORAL, ls="--", lw=1.5, label=f"Threshold ({thresh:.3f})"
    ),
    mpatches.Patch(
        color=GOLD, alpha=0.4, label=f"Horizon (−{HORIZON/FS_EFF*1000:.0f} ms)"
    ),
    plt.Line2D([0], [0], color=WHITE, lw=0.9, alpha=0.6, label="Button press"),
    plt.Line2D([0], [0], color=CORAL, lw=1.5, label="EEG (detecting)"),
]
ax_prob.legend(
    handles=leg_handles,
    loc="upper left",
    facecolor=CARD,
    labelcolor=WHITE,
    edgecolor=EDGE,
    fontsize=7,
    ncol=6,
)

# Animated artists
lines_eeg = [ax.plot([], [], lw=0.75, color=TEAL)[0] for ax in ax_eeg_flat]
(line_prob,) = ax_prob.plot([], [], color=TEAL, lw=1.8, zorder=5, alpha=0.85)
(line_gate,) = ax_prob.plot([], [], color="#a0c4ff", lw=1.2, zorder=4, alpha=0.70)

# Detection indicator (flashes coral when gated score is above threshold)
det_label = ax_prob.text(
    0.995,
    0.94,
    "⚡ DETECTION",
    transform=ax_prob.transAxes,
    color=CORAL,
    fontsize=9,
    fontweight="bold",
    ha="right",
    va="top",
    alpha=0.0,
)

title_obj = fig.suptitle(
    f"Subject {SUBJECT} · Trial {DEMO_TRIAL} · Live BCI Prediction",
    color=WHITE,
    fontsize=11,
    fontweight="bold",
    y=0.997,
)


# ── FuncAnimation ─────────────────────────────────────────────────────────────
def init():
    for ln in lines_eeg:
        ln.set_data([], [])
    line_prob.set_data([], [])
    line_gate.set_data([], [])
    return []


def update(frame):
    idx = min(T_OPT + frame * STEP, N_samp)  # current sample endpoint
    k_w = min(frame * STEP, N_wins - 1)  # current window index
    t_cur = idx / FS_EFF
    prob_smooth = float(scores_smooth[k_w])
    prob_gated = float(scores_gated[k_w])
    detecting = prob_gated >= thresh  # gate drives detection

    # ── EEG panels: fixed xlim, scrolling data ──────────────────────────────
    i0 = max(0, idx - EEG_WIN)
    n = idx - i0
    clr = CORAL if detecting else TEAL
    x_rel = t_eeg_rel[-n:]
    for ch, ln in enumerate(lines_eeg):
        ln.set_data(x_rel, X_raw[i0:idx, ch])
        ln.set_color(clr)

    # ── Probability panel: scrolling xlim ───────────────────────────────────
    i0_w = max(0, k_w - PROB_WIN)
    line_prob.set_data(t_wins[i0_w : k_w + 1], scores_smooth[i0_w : k_w + 1])
    line_gate.set_data(t_wins[i0_w : k_w + 1], scores_gated[i0_w : k_w + 1])
    t0_prob = max(0.0, t_cur - PROB_WIN_S)
    ax_prob.set_xlim(t0_prob, t0_prob + PROB_WIN_S)

    # ── Detection label ──────────────────────────────────────────────────────
    det_label.set_alpha(1.0 if detecting else 0.0)

    # ── Title ────────────────────────────────────────────────────────────────
    title_obj.set_text(
        f"Subject {SUBJECT} · Trial {DEMO_TRIAL} · "
        f"t = {t_cur:.1f} s  |  P_smooth = {prob_smooth:.3f}"
        f"  P_gated = {prob_gated:.3f}" + ("  ⚡" if detecting else "")
    )
    return []


print(
    f"Rendering {N_frames} frames at {FPS} fps "
    f"({STEP * FPS / FS_EFF:.2f}× real-time, "
    f"~{N_frames / FPS:.0f} s video) …"
)

ani = animation.FuncAnimation(
    fig,
    update,
    frames=N_frames,
    init_func=init,
    interval=1000 // FPS,
    blit=False,
)

os.makedirs("report", exist_ok=True)
out_path = f"report/live_demo_s{SUBJECT}_t{DEMO_TRIAL}_{TACHE}.mp4"
try:
    writer = animation.FFMpegWriter(
        fps=FPS,
        bitrate=2000,
        extra_args=["-vcodec", "libx264", "-pix_fmt", "yuv420p"],
    )
    ani.save(
        out_path,
        writer=writer,
        dpi=80,
        progress_callback=lambda i, n: print(f"\r  frame {i}/{n}", end="", flush=True),
    )
    print(f"\nSaved → {out_path}")
except Exception as exc:
    out_path = out_path.replace(".mp4", ".gif")
    print(f"FFmpeg unavailable ({exc}), saving GIF …")
    ani.save(
        out_path,
        writer="pillow",
        fps=max(FPS // 2, 5),
        dpi=60,
        progress_callback=lambda i, n: print(f"\r  frame {i}/{n}", end="", flush=True),
    )
    print(f"\nSaved → {out_path}")
finally:
    plt.close(fig)
